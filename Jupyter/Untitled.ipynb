# %%
import pandas as pd
datatrain = pd.read_csv('datatrain.csv',sep=';')
datatrain
# Out:
#                                       Title                    Artist  Year  \
# 0                                   Sunrise               Norah Jones  2004
# 1                               Black Night               Deep Purple  2000
# 2                             The Pretender              Foo Fighters  2007
# 3                    Waitin' On A Sunny Day         Bruce Springsteen  2002
# 4     The Road Ahead (Miles Of The Unknown)              City To City  2004
# ...                                     ...                       ...   ...
# 1390                             Summertime           Louis Armstrong  1958
# 1391                       Heartbreak Hotel             Elvis Presley  1958
# 1392                        Johnny B. Goode               Chuck Berry  1959
# 1393                              Take Five  The Dave Brubeck Quartet  1959
# 1394                         Blueberry Hill               Fats Domino  1959
#
#       Beats  Energy  Danceability  Loudness  Liveness  Valence  Duration  \
# 0       157      30            53       -14        11       68       201
# 1       135      79            50       -11        17       81       207
# 2       173      96            43        -4         3       37       269
# 3       106      82            58        -5        10       87       256
# 4        99      46            54        -9        14       14       247
# ...     ...     ...           ...       ...       ...      ...       ...
# 1390    168       7            17       -21        14       10       298
# 1391     94      21            70       -12        11       72       128
# 1392    168      80            53        -9        31       97       162
# 1393    174      26            45       -13         7       60       324
# 1394    133      50            49       -10        16       83       148
#
#       Acousticness  Speechiness  Popularity         Genre    id
# 0               94            3          71  ALTERNATIVOS     1
# 1               17            7          39          ROCK     2
# 2                0            4          76         METAL     3
# 3                1            3          59          ROCK     4
# 4                0            2          45          ROCK     5
# ...            ...          ...         ...           ...   ...
# 1390            92            3          66  ALTERNATIVOS  1391
# 1391            84            7          63  ALTERNATIVOS  1392
# 1392            74            7          74          ROCK  1393
# 1393            54            4          65     JAZZ FUNK  1394
# 1394            74            3          56  ALTERNATIVOS  1395
#
# [1395 rows x 15 columns]

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4628/4017920374.py in <module>
# ----> 1 from sklearn import svm
#       2 from sklearn.ensemble import RandomForestClassifier
#       3 from sklearn.linear_model import LogisticRegression
#       4 from sklearn.naive_bayes import GaussianNB
#       5 from sklearn.naive_bayes import MultinomialNB
#
# ModuleNotFoundError: No module named 'sklearn'
